# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql://root:1234@localhost:3306/uday')
properties = pd.read_sql_query('SELECT * FROM properties', engine)
properties.head()
# Out:
#    id  owner_id                                      name flat_no  \
# 0   1       442                        VS Willows, Ulsoor     405
# 1   2       120  SV Mayfair, Nallurahalli Main Rd blocked     009
# 2   3       348                          Raheja Residency     307
# 3   4       120          SV Mayfair, Nallurahalli Main Rd     210
# 4   5       352                  Adarsh Palm Retreat, T 3   B-302
#
#                                            addressl1     locality       city  \
# 0                                   #8, RK Mutt Road       Ulsoor  bengaluru
# 1      65/8A, Nallurahalli Rd, Siddapura, Whitefield   Whitefield  bengaluru
# 2  Near Wipro Park, Behind flipkart, koramangala ...  Koramangala  bengaluru
# 3      65/8A, Nallurahalli Rd, Siddapura, Whitefield   Whitefield  bengaluru
# 4                     B302, T3 Daffodills, Bellandur    Bellandur  bengaluru
#
#        state country  zipcode         ...           parking_number  metatitle  \
# ...

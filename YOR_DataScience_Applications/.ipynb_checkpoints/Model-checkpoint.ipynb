# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import sklearn
import seaborn as sns
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
from sqlalchemy import create_engine
import numpy as np


# engine = create_engine('mysql://root:1234@localhost:3306/uday')

# %%
query = "select * from properties"
properties = pd.read_sql_query(query, engine,index_col= 'id')
# properties

plt.figure(figsize=(10,10))
plt.plot(properties.sqftsuper, properties.rent, 'b.')
plt.ylabel('rent')
plt.xlabel('sqrft')
plt.show()

# %%
query = "select * from rooms"
rooms = pd.read_sql_query(query, engine,index_col= 'id')
# rooms

plt.figure(figsize=(5,5))
plt.plot(rooms.sqftsuper, rooms.rent, 'b.')
plt.ylabel('rent')
plt.xlabel('sqrft')
plt.show()

# %%
locality = 'Koramangala'
city = 'bengaluru'

user_minimum_Budget = 14000
user_maximum_Budget = 21000


from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="specify_your_app_name_here")
location = geolocator.geocode(locality + ", " + city)
print(location.longitude, location.latitude)

gender = str(2)
propertyType = 'all'
# Out:
# 77.6222304 12.9340114

# %%
import mpu
# import radians
from math import sin, cos, sqrt, atan2, radians
def way1():
    lat1 = 52.2296756
    lon1 = 21.0122287
    lat2 = 52.406374
    lon2 = 16.9251681
    dist = mpu.haversine_distance((lat1, lon1), (lat2, lon2))
    print("Way1 : ",dist)
    
def way2():
    R = 6373.0
    
    lat1 = radians(52.2296756)
    lon1 = radians(21.0122287)
    lat2 = radians(52.406374)
    lon2 = radians(16.9251681)

    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = (sin(dlat/2))**2 + cos(lat1) * cos(lat2) * (sin(dlon/2))**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    distance = R * c
    print ("way2 : ", distance)
    
import time
start_time = time.time()
way1()
print("--- %s seconds ---" % (time.time() - start_time))
start_time = time.time()
way2()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Way1 :  278.45817507541943
# --- 0.0 seconds ---
# way2 :  278.54558935106695
# --- 0.0 seconds ---

# %%
import mpu
# import radians
from math import sin, cos, sqrt, atan2, radians
def tway1():
    from geopy.geocoders import Nominatim
    geolocator = Nominatim(user_agent="specify_your_app_name_here")
    location = geolocator.geocode(locality + ", " + city)
    print("Way1 : ",location.longitude, location.latitude)
    
def tway2():
   
    print ("way2 : ",)
    
import time
start_time = time.time()
tway1()
print("--- %s seconds ---" % (time.time() - start_time))
start_time = time.time()
tway2()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Way1 :  77.6222304 12.9340114
# --- 0.664743185043335 seconds ---
# way2 :
# --- 0.0 seconds ---

# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %%
if(propertyType == 'family'):
#     query = "select * from properties p where (p.status = \'available\') and (p.city = \'"+city+"\') and (p.locality = \'" + locality + "\') "
    query = "select * from properties p where p.city = 'bengaluru' and p.status = 'available'"
elif(gender != '0'):
    query = "select * from properties p where (p.status = 'partial' or p.status = 'available') and p.city = \'" + city + "\' and p.gender = " + gender
else:
    query = "select * from properties p where (p.status = 'partial' or p.status = 'available') and p.city = \'" + city + "\'"
print(query)
# Out:
# select * from properties p where (p.status = 'partial' or p.status = 'available') and p.city = 'bengaluru' and p.gender = 2

# %%
engine = create_engine('mysql://root:1234@localhost:3306/uday')
properties = pd.read_sql_query(query, engine,index_col= 'id')
properties
# Out:
#      owner_id                                     name flat_no  \
# id
# 33        878  DLF Maiden Heights A-9, Electronic City     091
# 38        801                           NR Springwoods    #006
# 81        911                            Golden Corner   C-020
# 99       1052                          Maruti Grandeur   F-105
# 119      1138            Prestige Ferns Residency T 19   19111
# 160      1475                       Prestige Park View    1051
# 224      1867                             RR Residency    B309
#
#                                              addressl1           locality  \
# id
# 33                                              Jigani    Electronic City
# 38   115, Dr. Shivaramkaranth Nagar, Sri Balaji Kru...  Manyata Tech Park
# 81   10/2-B, Sarjapur Main Rd Bellandur Bengaluru, ...      Sarjapur Road
# 99    Green Glen Layout, Bellandur, Bengaluru, Karn...          Bellandur
# 119                                       Haralur Road       Haralur Road
# 160                                 hope farm junction         WHitefield
# 224  22, Hosapalaya Main Rd, Hosapalya, Muneshwara ...         HSR Layout
#
#           city      state country  zipcode  sqftsuper         ...           \
# id                                                            ...
# 33   bengaluru  karnataka   india   560105       1230         ...
# 38   bengaluru  karnataka   india   560077       1752         ...
# 81   bengaluru  karnataka   india   560103          0         ...
# 99   bengaluru  karnataka   india   560103       1874         ...
# 119  bengaluru  karnataka   india   560102          0         ...
# 160  bengaluru  karnataka   india   560066       1740         ...
# 224  bengaluru  karnataka   india   560068       1800         ...
#
#      parking_number metatitle metakeyword  metadescription  assign_to  golden  \
# id
# 33             NULL      NULL        NULL             NULL       NULL       0
# 38             NULL                                              NULL       0
# 81                0                                              NULL       0
# 99                0                                              NULL       0
# 119               0                                              NULL       0
# 160               0                                              NULL       0
# 224               0                                              NULL       0
#
#      partner  showinhomepage           created_at           updated_at
# id
# 33         0               0  2016-09-13 01:33:46  2018-09-22 00:10:49
# 38         0               0  2016-09-14 05:39:29  2018-12-31 00:10:55
# 81         0               0  2017-03-23 18:32:15  2018-09-29 10:50:23
# 99         0               0  2017-06-21 20:12:48  2018-10-28 12:43:17
# 119        0               0  2017-08-12 13:06:55  2018-12-25 00:12:56
# 160        0               0  2018-01-18 18:19:49  2018-08-31 18:11:32
# 224        0               0  2018-05-28 11:09:04  2018-10-30 20:22:09
#
# [7 rows x 61 columns]

# %%
properties.columns
# Out:
# Index(['owner_id', 'name', 'flat_no', 'addressl1', 'locality', 'city', 'state',
#        'country', 'zipcode', 'sqftsuper', 'image', 'images', 'type',
#        'sharetype', 'baths', 'kitchens', 'washrooms', 'totalrooms',
#        'availrooms', 'rent', 'owner_rent', 'parkingcharges', 'deposite',
#        'maintenance', 'status', 'availfrom', 'availto', 'tenure', 'details',
#        'notes', 'cntrestaurants', 'cnthospitals', 'cntgyms', 'cnttheater',
#        'cntmalls', 'workdistance', 'latitude', 'longitude', 'blockname',
#        'gender', 'tag_as', 'commpercentage', 'tds', 'actualOSAmount',
#        'pendingOSAmount', 'amountRemark', 'minimumGuranteeIsActive',
#        'minimumGuranteeAmount', 'minimumGuranteeStart', 'minimumGuranteeEnd',
#        'propertyrules', 'parking_number', 'metatitle', 'metakeyword',
#        'metadescription', 'assign_to', 'golden', 'partner', 'showinhomepage',
#        'created_at', 'updated_at'],
#       dtype='object')

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="specify_your_app_name_here")
location = geolocator.geocode(locality + ", " + city)
R = 6373.0   
lat1 = radians(location.latitude)
lon1 = radians(location.longitude)
distance = pd.DataFrame(data = np.zeros(properties.shape[0], dtype=float), index = properties.index, columns = ['distance'])

for i in properties.index:
    lat2 = radians(properties.at[i,'latitude'])
    lon2 = radians(properties.at[i,'longitude'])
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = (sin(dlat/2))**2 + cos(lat1) * cos(lat2) * (sin(dlon/2))**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    d = R * c
    distance.at[i,'distance']  = d
print(distance)

distanceClassify = pd.DataFrame(data = np.zeros((properties.shape[0], 3), dtype=int), index = properties.index, columns = ['distanceLessThan5KM','distanceLessThan10KM','distanceGreaterThan10KM'])
for i in properties.index:
    if(distance.at[i,'distance'] <= 5.0):
        distanceClassify.at[i,'distanceLessThan5KM'] = 6
    elif(distance.at[i,'distance'] <= 10.0):
        distanceClassify.at[i,'distanceLessThan10KM'] = 5
    else:
        distanceClassify.at[i,'distanceGreaterThan10KM'] = 4
print(distanceClassify)
# Out:
#       distance
# id
# 33   17.118352
# 38   14.770439
# 81    5.388675
# 99    5.405775
# 119   5.517932
# 160  14.952240
# 224   4.602619
#      distanceLessThan5KM  distanceLessThan10KM  distanceGreaterThan10KM
# id
# 33                     0                     0                        4
# 38                     0                     0                        4
# 81                     0                     5                        0
# 99                     0                     5                        0
# 119                    0                     5                        0
# 160                    0                     0                        4
# 224                    6                     0                        0

# %%
# type = pd.DataFrame(data = np.zeros((properties.shape[0], 3), dtype = int), index = properties.index, columns = ['flat', 'villa', 'house'])
# for i in properties.index: 
#     type.at[i,properties.at[i,'type']] = 1
# type

# %%
parking = pd.DataFrame(data = np.zeros(properties.shape[0], dtype = int), columns = ['parking'], index = properties.index)
for i in properties.index:
    parking.at[i,'parking'] = 0 if (properties.at[i,'parkingcharges'] == 0) else 1
parking
# Out:
#      parking
# id
# 33         1
# 38         0
# 81         0
# 99         0
# 119        0
# 160        0
# 224        0

# %%
minBudget = 12000
maxBudget = 29000

# %%
minimum_property_rent = min(properties.rent)
maximum_property_rent = max(properties.rent)

theMinBudget = minimum_property_rent if minimum_property_rent < minBudget else minBudget
theMaxBudget = maximum_property_rent if maximum_property_rent > maxBudget else maxBudget
print(theMinBudget, theMaxBudget)
# Out:
# 12000 48000

# %%
# numBy1000 = (theMaxBudget // 1000) - (theMinBudget // 1000) + 1 
# print(numBy1000)
# num = (theMinBudget // 1000)
minNum = (theMinBudget // 5000) * 5000
maxNum = (theMaxBudget // 5000) * 5000



budgetList = []
for i in range(minNum,maxNum + 1,5000):
    budgetName = "rent-" + str(i)+"-"+str(i + 5000)
    budgetList.append(budgetName)
print(budgetList)
# Out:
# ['rent-10000-15000', 'rent-15000-20000', 'rent-20000-25000', 'rent-25000-30000', 'rent-30000-35000', 'rent-35000-40000', 'rent-40000-45000', 'rent-45000-50000']

# %%
areaTypes = ['areaLessThan1000','areaLessThan1700','areaGreaterThan1700']
area  = pd.DataFrame(data = np.zeros((properties.shape[0],3), dtype = int), index  = properties.index, columns = areaTypes)
for i in properties.index:
    if(properties.at[i,'sqftsuper'] < 1000):
        area.at[i,'areaLessThan1000'] = 5
    elif(properties.at[i,'sqftsuper'] < 1700):
        area.at[i,'areaLessThan1700'] = 6
    else:
        area.at[i,'areaGreaterThan1700'] = 7
area
# Out:
#      areaLessThan1000  areaLessThan1700  areaGreaterThan1700
# id
# 33                  0                 6                    0
# 38                  0                 0                    7
# 81                  5                 0                    0
# 99                  0                 0                    7
# 119                 5                 0                    0
# 160                 0                 0                    7
# 224                 0                 0                    7

# %%
bussinessTypes = ['managed','marketplace']
businessType = pd.DataFrame(np.zeros((properties.shape[0], 2), dtype = int), columns = bussinessTypes, index = properties.index)
for i in properties.index:
    if(properties.at[i,'tag_as'] == 'managed'):
        businessType.at[i,'managed'] = 7
    else:
        businessType.at[i,'marketplace'] = 5
businessType
# Out:
#      managed  marketplace
# id
# 33         0            5
# 38         7            0
# 81         0            5
# 99         0            5
# 119        0            5
# 160        0            5
# 224        0            5

# %%
properties.columns
# Out:
# Index(['owner_id', 'name', 'flat_no', 'addressl1', 'locality', 'city', 'state',
#        'country', 'zipcode', 'sqftsuper', 'image', 'images', 'type',
#        'sharetype', 'baths', 'kitchens', 'washrooms', 'totalrooms',
#        'availrooms', 'rent', 'owner_rent', 'parkingcharges', 'deposite',
#        'maintenance', 'status', 'availfrom', 'availto', 'tenure', 'details',
#        'notes', 'cntrestaurants', 'cnthospitals', 'cntgyms', 'cnttheater',
#        'cntmalls', 'workdistance', 'latitude', 'longitude', 'blockname',
#        'gender', 'tag_as', 'commpercentage', 'tds', 'actualOSAmount',
#        'pendingOSAmount', 'amountRemark', 'minimumGuranteeIsActive',
#        'minimumGuranteeAmount', 'minimumGuranteeStart', 'minimumGuranteeEnd',
#        'propertyrules', 'parking_number', 'metatitle', 'metakeyword',
#        'metadescription', 'assign_to', 'golden', 'partner', 'showinhomepage',
#        'created_at', 'updated_at'],
#       dtype='object')

# %%
properties = properties.drop(['owner_id', 'name', 'flat_no', 'addressl1', 'locality', 'city', 'state',
       'country', 'zipcode','image', 'images', 'sharetype', 'baths', 'kitchens', 'washrooms', 'totalrooms','availrooms','owner_rent', 'status','details',
       'notes', 'cntrestaurants', 'cnthospitals', 'cntgyms', 'cnttheater',
       'cntmalls', 'workdistance', 'latitude', 'longitude', 'blockname','commpercentage', 'tds', 'actualOSAmount',
       'pendingOSAmount', 'amountRemark', 'minimumGuranteeIsActive',
       'minimumGuranteeAmount', 'minimumGuranteeStart', 'minimumGuranteeEnd',
       'propertyrules', 'parking_number', 'metatitle', 'metakeyword',
       'metadescription', 'assign_to','partner', 'showinhomepage',
       'created_at', 'updated_at', 'type','parkingcharges','gender','sqftsuper','tag_as'], axis=1)
properties
# Out:
#       rent  deposite  maintenance   availfrom     availto  tenure  golden
# id
# 33   29700     89100            0  2016-09-12  2017-09-12       6       0
# 38   26460     79380         3867  2018-06-14  2019-09-09      12       0
# 81   38000    114000            0  2018-02-17  2019-01-17      11       0
# 99   48000    144000            0  2018-06-01  2019-05-01      11       0
# 119  41000    123000            0  2017-09-01  2019-12-12      24       0
# 160  47000    141000            0  2018-01-30  2018-12-30      11       0
# 224  46000    138000            0  2018-05-23  2019-04-23      11       0

# %%
propertiesColumns = budgetList

propertyUnifiedVector = pd.DataFrame(np.zeros((properties.shape[0],len(propertiesColumns)), dtype = float), columns = propertiesColumns, index = properties.index)
propertyUnifiedVector = pd.concat([propertyUnifiedVector, distanceClassify, businessType, area], axis = 1)

for i in properties.index:
    rent = properties.at[i,'rent']
    rent = (rent // 5000) * 5000
    budgetName = "rent-" + str(rent)+"-"+str(rent + 5000)
    propertyUnifiedVector.at[i, budgetName] = 8
propertyUnifiedVector
# Out:
#      rent-10000-15000  rent-15000-20000  rent-20000-25000  rent-25000-30000  \
# id
# 33                0.0               0.0               0.0               8.0
# 38                0.0               0.0               0.0               8.0
# 81                0.0               0.0               0.0               0.0
# 99                0.0               0.0               0.0               0.0
# 119               0.0               0.0               0.0               0.0
# 160               0.0               0.0               0.0               0.0
# 224               0.0               0.0               0.0               0.0
#
#      rent-30000-35000  rent-35000-40000  rent-40000-45000  rent-45000-50000  \
# id
# 33                0.0               0.0               0.0               0.0
# 38                0.0               0.0               0.0               0.0
# 81                0.0               8.0               0.0               0.0
# 99                0.0               0.0               0.0               8.0
# 119               0.0               0.0               8.0               0.0
# 160               0.0               0.0               0.0               8.0
# 224               0.0               0.0               0.0               8.0
#
#      distanceLessThan5KM  distanceLessThan10KM  distanceGreaterThan10KM  \
# id
# 33                     0                     0                        4
# 38                     0                     0                        4
# 81                     0                     5                        0
# 99                     0                     5                        0
# 119                    0                     5                        0
# 160                    0                     0                        4
# 224                    6                     0                        0
#
#      managed  marketplace  areaLessThan1000  areaLessThan1700  \
# id
# 33         0            5                 0                 6
# 38         7            0                 0                 0
# 81         0            5                 5                 0
# 99         0            5                 0                 0
# 119        0            5                 5                 0
# 160        0            5                 0                 0
# 224        0            5                 0                 0
#
#      areaGreaterThan1700
# id
# 33                     0
# 38                     7
# 81                     0
# 99                     7
# 119                    0
# 160                    7
# 224                    7

# %%
budgets = (8 * np.ones( len(budgetList))).tolist() + [6,5,4,7,5,5,6,7]
userUnifiedVector = pd.DataFrame([budgets]  , columns = propertyUnifiedVector.columns, index =[1])
userUnifiedVector
# Out:
#    rent-10000-15000  rent-15000-20000  rent-20000-25000  rent-25000-30000  \
# 1               8.0               8.0               8.0               8.0
#
#    rent-30000-35000  rent-35000-40000  rent-40000-45000  rent-45000-50000  \
# 1               8.0               8.0               8.0               8.0
#
#    distanceLessThan5KM  distanceLessThan10KM  distanceGreaterThan10KM  \
# 1                    6                     5                        4
#
#    managed  marketplace  areaLessThan1000  areaLessThan1700  \
# 1        7            5                 5                 6
#
#    areaGreaterThan1700
# 1                    7

# %%
UserPropertyDistance = sklearn.metrics.pairwise.cosine_similarity(userUnifiedVector.values,propertyUnifiedVector.values)
UserPropertyDistance = pd.DataFrame(UserPropertyDistance,columns = propertyUnifiedVector.index)
# UserPropertyDistance.index = ['rank']

# %%
UserPropertyDistance
# Out:
# id      33        38        81        99        119       160       224
# 0   0.42709  0.479866  0.424051  0.459202  0.424051  0.446345  0.474444

# %%
finalDF = pd.DataFrame({'propertyId': properties.index,  'rank' : UserPropertyDistance.loc[0].tolist()})
finalDF
# Out:
#    propertyId      rank
# 0          33  0.427090
# 1          38  0.479866
# 2          81  0.424051
# 3          99  0.459202
# 4         119  0.424051
# 5         160  0.446345
# 6         224  0.474444

# %%
# ‘split’,’records’,’index’,’table’
out = finalDF.to_json(orient= 'records')
out
# Out:
# '[{"propertyId":33,"rank":0.4270903998},{"propertyId":38,"rank":0.4798663031},{"propertyId":81,"rank":0.4240505718},{"propertyId":99,"rank":0.4592023006},{"propertyId":119,"rank":0.4240505718},{"propertyId":160,"rank":0.4463449376},{"propertyId":224,"rank":0.4744439109}]'

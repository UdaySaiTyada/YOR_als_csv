# %%
import pandas as pd
propertyUsers = pd.read_csv('propertiesUsers.csv', index_col = 'id')
propertyUsers
# Out:
#       user_id  property_id  room_id   rent  parkingcharges  deposite  \
# id
# 4         174            1        1  10395             0.0     30000
# 5         175            1        2  10395             0.0     30000
# 6         183            1        3  12600             0.0     36000
# 7         179           10       29  13300             0.0     37500
# 8         131           10       30  15000             0.0     41700
# ...       ...          ...      ...    ...             ...       ...
# 1231     2899          316      738   8000             0.0      8000
# 1232     2901          179      446   6500             0.0      6500
# 1233     2908          307      715  15000             0.0         0
# 1234     2912           46      123   7500             0.0         0
# 1235     2913           46      123   7500             0.0         0
#
#       pendingdeposite  maintainance   occupfrom     occupto  ...  amenities  \
# ...
